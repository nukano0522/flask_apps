# %% [markdown]
# # PythonからDataLakeのデータを処理

# %%
import os, uuid, sys
from azure.storage.filedatalake import DataLakeServiceClient
from azure.core._match_conditions import MatchConditions
from azure.storage.filedatalake._models import ContentSettings

# %%
def initialize_storage_account(storage_account_name, storage_account_key):
    
    try:  
        global service_client

        service_client = DataLakeServiceClient(account_url="{}://{}.dfs.core.windows.net".format(
            "https", storage_account_name), credential=storage_account_key)
    
    except Exception as e:
        print(e)

# %%
storage_account_name = "nukano0522azurestorage02"
# storage_account_key = "DefaultEndpointsProtocol=https;AccountName=nukano0522azurestorage02;AccountKey=oHq+kZfmwpZTXbtaIUSsq1cpyKkVFgLjXS6PtRKGpm3QOktwJs8679aQ4Lo0kyuICqZp+OV/Rny6+AStlTUaiQ==;EndpointSuffix=core.windows.net"
storage_account_key = "oHq+kZfmwpZTXbtaIUSsq1cpyKkVFgLjXS6PtRKGpm3QOktwJs8679aQ4Lo0kyuICqZp+OV/Rny6+AStlTUaiQ=="
initialize_storage_account(storage_account_name, storage_account_key)

# %%
# コンテナー作成
# def create_file_system():
#     try:
#         global file_system_client

#         file_system_client = service_client.create_file_system(file_system="my-file-system")
    
#     except Exception as e:
#         print(e)

# create_file_system()

# %%
def download_file_from_directory():
    try:
        file_system_client = service_client.get_file_system_client(file_system="nukano0522container01")
        directory_client = file_system_client.get_directory_client("image_detection/model")
        local_file = open("c:\\Users\\nukan\\Desktop\\work\\git\\flask_apps\\model.pt",'wb')
        file_client = directory_client.get_file_client("model.pt")
        download = file_client.download_file()
        downloaded_bytes = download.readall()
        local_file.write(downloaded_bytes)
        local_file.close()

    except Exception as e:
     print(e)

# %%
download_file_from_directory()

# %% [markdown]
# # azure cliを利用したapp serviceデプロイ

# %% [markdown]
# powershell -c Compress-Archive -Path "./image_detection/*" -DestinationPath ./deploy/image_detection.zip
# <br>
# az login
# <br>
# az webapp deploy --resource-group azure_for_personal_use --name flask-image-detection --src-path ../deploy/image_detection.zip
#
# <br>
# Get-ChildItem -Path . -File -Recurse -Exclude *.pt | Compress-Archive -Update -DestinationPath ../deploy/image_detection.zip

# %%
import torch, torchvision

# %%
model = torch.load("./model/image_detection/model.pt")
model.state_dict(torch.load("./model/image_detection/model.pt"))
# Out:
# c:\Users\nukan\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1365: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# セル12 を c:\Users\nukan\Desktop\work\git\flask_apps\検証.ipynb in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/nukan/Desktop/work/git/flask_apps/%E6%A4%9C%E8%A8%BC.ipynb#ch0000011?line=0'>1</a> model = torch.load("./model/image_detection/model.pt")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nukan/Desktop/work/git/flask_apps/%E6%A4%9C%E8%A8%BC.ipynb#ch0000011?line=1'>2</a> model.state_dict(torch.load("./model/image_detection/model.pt"))
#
# ...

# %%
model
# Out:
# MaskRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=0.0)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
def test():
    global tmp
    tmp = 2


tmp
# Out:
# 2
